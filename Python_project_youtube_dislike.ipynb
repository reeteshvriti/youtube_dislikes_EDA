# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve 5 and bottom 5 records.

# %%
data = pd.read_csv('youtube_dislike_dataset.csv')
print(data.head())  # head function will display the first 5 elements 
print(data.tail())  # tail function will display the last 5 elements
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4       #NAME?                Why Retaining Walls Collapse
#
#                  channel_id          channel_title      published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  01-07-2021 10:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  10-06-2021 16:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  20-09-2021 01:03
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  03-03-2021 10:00
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  07-12-2021 13:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# 2      925281   11212       401            831
# 3     2641597   39131       441           3745
# 4      715724   32887       367           1067
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
# 1  Migos Avalanche Quality Control Music/Motown R...
# 2
# 3  PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4  retaining wall New Jersey highway Direct Conne...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
# 1  Watch the the official video for Migos - "Aval...
# 2  Hannah Waddingham wins the Emmy for Supporting...
# 3  JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4  One of the most important (and innocuous) part...
#
#                                             comments
# 0  Respect to Dortmund fans,must be sad losing hi...
# 1  Migos just makes me want to live my live to th...
# 2  Hannah's energy bursts through any screen. Wel...
# 3  youngVer><  REN is really PERFECT. It's not ju...
# 4   Keep up with all my projects here: https://pr...
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title      published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  12-02-2021 05:03
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  16-01-2021 05:39
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  02-06-2021 09:00
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  20-10-2020 20:59
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  23-05-2021 21:00
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...
# 37418  Montrezl Harrell is going crazy with the rebou...
# 37419  I honestly do not know why this song hit so ha...
# 37420  Foi um prazer passar esta tarde com vocs debat...
# 37421  Thank you Kane for everything you have given t...

# %% [markdown]
# #  2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df = pd.DataFrame(data)
check_info = df.info()

print(check_info)
print(df.shape)

# The Shape of the data is, the data contain 37422 rows and 12 columns
# In the given data 4 columns contain numeric data and the rest 8 columns contain either string data 
#  or data having both numeric and non numeric data.
# The comments columns contain null values 158 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# None
# (37422, 12)

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
len_of_data = len(df)
sum_of_null = data['title'].isnull().sum()
per = (sum_of_null / len_of_data) * 100
print(per) # to calculate the percentage of the missing data

#  dropping the missing values
print("#"*30)
df.dropna()
a = df.isnull().sum()
a
# 0.42% of data is missing in the comment column
# Out:
# 0.0
# ##############################
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
# now we are splitting the categorical and continous variable 

cont_var = df.loc[0:, (df.dtypes=='int64') | (df.dtypes=='float64')]  #continous variable data

cate_var = df.loc[0:, df.dtypes=='object']  #categorical variable data


# now describing the statistics of the data

print("Statistics of continous variable \n\n\n",cont_var.describe()) 
print("\n\n\n\n Statictics of categorical variable \n\n\n", cate_var.describe())

# The Continous variable  data contain the count, mean, std, min, max, etc
# The categorical varibale data contain the frequency, count, top, unique
# Out:
# Statistics of continous variable
#
#
#           view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07
#
#
#
#
#  Statictics of categorical variable
#
#
#         video_id  title                channel_id        channel_title  \
# count     37422  37422                     37422                37422
# unique    36964  37111                     10961                10880
# top      #NAME?    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq        459     21                       533                  533
#
#             published_at   tags description  \
# count              37422  37422       37422
# unique             30031  28788       35630
# top     18-09-2020 04:00
# freq                  18   3817         589
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
df['published_at'] =  pd.to_datetime(df['published_at'])

# here we have used to_datetime function to convert the data to date time format

# %% [markdown]
# # 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month_num'] = pd.DatetimeIndex(df['published_at']).month
df
# here we have used the pandas inbuilt function DatetimeIndex  and extracting the month
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-01-07 10:00:00
# 1      UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-10-06 16:00:00
# 2      UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:00
# 3      UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:00
# 4      UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-07-12 13:00:00
# ...                         ...                    ...                 ...
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q               Lil Tjay 2021-12-02 05:03:00
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                    NBA 2021-01-16 05:39:00
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA                MAMAMOO 2021-02-06 09:00:00
# 37420  UC8NjnNWMsRqq11NYvHAQb1g         Master Podcast 2020-10-20 20:59:00
# 37421  UCEg25rdRZXg32iwai6N6l0w      Tottenham Hotspur 2021-05-23 21:00:00
#
#        view_count    likes  dislikes  comment_count  \
# 0         1048888    19515       226           1319
# 1        15352638   359277      7479          18729
# 2          925281    11212       401            831
# 3         2641597    39131       441           3745
# 4          715724    32887       367           1067
# ...           ...      ...       ...            ...
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 0      football soccer ftbol alemn Bundesliga season ...
# 1      Migos Avalanche Quality Control Music/Motown R...
# 2
# 3      PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4      retaining wall New Jersey highway Direct Conne...
# ...                                                  ...
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 0      Enjoy the best skills and goals from Jadon San...
# 1      Watch the the official video for Migos - "Aval...
# 2      Hannah Waddingham wins the Emmy for Supporting...
# 3      JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4      One of the most important (and innocuous) part...
# ...                                                  ...
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments  published_month_num
# 0      Respect to Dortmund fans,must be sad losing hi...                    1
# 1      Migos just makes me want to live my live to th...                   10
# 2      Hannah's energy bursts through any screen. Wel...                    9
# 3      youngVer><  REN is really PERFECT. It's not ju...                    3
# 4       Keep up with all my projects here: https://pr...                    7
# ...                                                  ...                  ...
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...                   12
# 37418  Montrezl Harrell is going crazy with the rebou...                    1
# 37419  I honestly do not know why this song hit so ha...                    2
# 37420  Foi um prazer passar esta tarde com vocs debat...                   10
# 37421  Thank you Kane for everything you have given t...                    5
#
# [37422 rows x 13 columns]

# %% [markdown]
# # 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.

# %%
dict1 = {1:'jan',2:'feb', 3:'mar', 4:'apr',5:'may', 6:'jun', 7:'jul',8:'aug', 9:'sep', 10:'oct', 
11:'nov',12:'dec'}
df['published_month'] = df['published_month_num'].replace(dict1)
df

# here we have used the dictionry method to replace the months with the name of the months
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-01-07 10:00:00
# 1      UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-10-06 16:00:00
# 2      UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:00
# 3      UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:00
# 4      UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-07-12 13:00:00
# ...                         ...                    ...                 ...
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q               Lil Tjay 2021-12-02 05:03:00
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                    NBA 2021-01-16 05:39:00
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA                MAMAMOO 2021-02-06 09:00:00
# 37420  UC8NjnNWMsRqq11NYvHAQb1g         Master Podcast 2020-10-20 20:59:00
# 37421  UCEg25rdRZXg32iwai6N6l0w      Tottenham Hotspur 2021-05-23 21:00:00
#
#        view_count    likes  dislikes  comment_count  \
# 0         1048888    19515       226           1319
# 1        15352638   359277      7479          18729
# 2          925281    11212       401            831
# 3         2641597    39131       441           3745
# 4          715724    32887       367           1067
# ...           ...      ...       ...            ...
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 0      football soccer ftbol alemn Bundesliga season ...
# 1      Migos Avalanche Quality Control Music/Motown R...
# 2
# 3      PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4      retaining wall New Jersey highway Direct Conne...
# ...                                                  ...
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 0      Enjoy the best skills and goals from Jadon San...
# 1      Watch the the official video for Migos - "Aval...
# 2      Hannah Waddingham wins the Emmy for Supporting...
# 3      JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4      One of the most important (and innocuous) part...
# ...                                                  ...
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments  published_month_num  \
# 0      Respect to Dortmund fans,must be sad losing hi...                    1
# 1      Migos just makes me want to live my live to th...                   10
# 2      Hannah's energy bursts through any screen. Wel...                    9
# 3      youngVer><  REN is really PERFECT. It's not ju...                    3
# 4       Keep up with all my projects here: https://pr...                    7
# ...                                                  ...                  ...
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...                   12
# 37418  Montrezl Harrell is going crazy with the rebou...                    1
# 37419  I honestly do not know why this song hit so ha...                    2
# 37420  Foi um prazer passar esta tarde com vocs debat...                   10
# 37421  Thank you Kane for everything you have given t...                    5
#
#       published_month
# 0                 jan
# 1                 oct
# 2                 sep
# 3                 mar
# 4                 jul
# ...               ...
# 37417             dec
# 37418             jan
# 37419             feb
# 37420             oct
# 37421             may
#
# [37422 rows x 14 columns]

# %% [markdown]
# # 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
groups = df.groupby('published_month')['published_month_num'].sum().sort_values(ascending=False)
groups
# here we have used in groupby method to group and arrange video count according to the months in decreasing order
# In  maximum number of  videos were published in november month
# Less number of videos were published in january month
# Out:
# published_month
# nov    46508
# oct    43060
# sep    38493
# aug    32248
# dec    30072
# jul    19173
# jun    16116
# may    12135
# apr     9644
# mar     8118
# feb     4906
# jan     2652
# Name: published_month_num, dtype: int64

# %% [markdown]
# # 9. Find the count of unique video_id, channel_id and channel_title.

# %%
video_i =  df['video_id'].nunique()
channel_i = df.channel_id.nunique()
channel_tit = df.channel_title.nunique()
print("Count of Unique video id :- ", video_i)
print("Count of unique channel id :- ", channel_i)
print("Count of unique channel title :- ", channel_tit)

# Here we have used the unique function to find the unqiue count
# 36964 unique video id are present
# 10961 unique channel id are present
# 10880 unique channel title are present
# Out:
# Count of Unique video id :-  36964
# Count of unique channel id :-  10961
# Count of unique channel title :-  10880

# %% [markdown]
# # 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos

# %%
group1 = df.groupby('channel_title')['published_at'].count().to_frame().sort_values('published_at', ascending=True)
print("Bottom 10 having lowest number of videos\n\n")
print(group1.head(10))
print("\n\nTop 10 having highest number of videos\n\n\n")
print(group1.tail(10))

# here we have used the count function and sort_value function to count and sort the values accordingly
# Out:
# Bottom 10 having lowest number of videos
#
#
#                               published_at
# channel_title
#    SilverName                            1
# Mini Muka                                1
# Mini Ladd                                1
# MindYourLogic                            1
# Mind Body Tonic With Dr Sita             1
# Mimi Ar                                  1
# Millyz                                   1
# Milkair                                  1
# Milissa Grande                           1
# MikuruSong                               1
#
#
# Top 10 having highest number of videos
#
#
#
#                      published_at
# channel_title
# NHL                            86
# FORMULA 1                      87
# SSundee                        98
# SSSniperWolf                   99
# WWE                           122
# NFL                           162
# NBA                           209
# BT Sport                      246
# The United Stand              301
# Sky Sports Football           533

# %% [markdown]
# # 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
max_likes = df.groupby('title')['likes'].max().to_frame().sort_values('likes', ascending=False)
# max_likes = group2.head(1)
maxi_lik = max_likes.head(1)
print("maximum likes -> ", maxi_lik)

min_likes =  df.groupby('title')['likes'].min().to_frame().sort_values('likes', ascending=True)
mini_lik = min_likes.head(1)
print("minimum likes -> ", mini_lik)
# Out:
# maximum likes ->                                    likes
# title
# BTS () 'Dynamite' Official MV  31837675
# minimum likes ->                                                      likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0

# %% [markdown]
# ## Infrenecing from the above data
#
# #### The  BTS () 'Dynamite' Official MV video has maximum number of likes from the given data set that is 31837675
# #### Kim Kardashian's Must-See Moments on "Saturday ... has the minimum number of likes from the given dataset that is 0

# %% [markdown]
# # 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences

# %%
max_dislikes = df.groupby('title')['dislikes'].max().to_frame().sort_values('dislikes', ascending=False)
maxi_dis = max_dislikes.head(1)
print(maxi_dis)

min_dislikes = df.groupby('title')['dislikes'].max().to_frame().sort_values('dislikes', ascending=True)
mini_dis = min_dislikes.head(1)
print(mini_dis)
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0

# %% [markdown]
# ## Infrenecing from the above data
#
# ### Cuties | Official Trailer | Netflix video  has maximum number of dislikes that is 2397733
# ### Kim Kardashian's Must-See Moments on Saturday ... video has minimum number of dislikes that is -> 0

# %% [markdown]
# # 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
sns.scatterplot( 'dislikes','view_count', data=df)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dislikes', ylabel='view_count'>

# %%
df.dislikes.describe()
# Out:
# count    3.742200e+04
# mean     4.989862e+03
# std      3.070824e+04
# min      0.000000e+00
# 25%      2.810000e+02
# 50%      7.960000e+02
# 75%      2.461750e+03
# max      2.397733e+06
# Name: dislikes, dtype: float64

# %% [markdown]
# ## From the above scatter plot we can infer that.
# ### As the number of views count increases the dislikes decreases.
# ### Thier are 3 outliers.

# %% [markdown]
# # 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January

# %%
jan_month = df[df['published_at'].dt.month==1]
print("\n\njanuary month description ", jan_month.describe())
print(jan_month.info())
print("*"*100)
print(jan_month.describe())


# Thier are 0 non null values
#
# Out:
# january month description           view_count         likes       dislikes  comment_count  \
# count  2.652000e+03  2.652000e+03    2652.000000   2.652000e+03
# mean   4.896377e+06  1.459908e+05    4272.257164   9.196232e+03
# std    1.475755e+07  3.961011e+05   20264.769436   5.677935e+04
# min    2.036800e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.941495e+05  1.262700e+04     273.750000   9.147500e+02
# 50%    1.240674e+06  3.970900e+04     759.000000   2.355000e+03
# 75%    3.693094e+06  1.209325e+05    2346.000000   6.326250e+03
# max    2.497840e+08  9.008309e+06  550853.000000   2.516058e+06
#
#        published_month_num
# count               2652.0
# mean                   1.0
# std                    0.0
# min                    1.0
# 25%                    1.0
# 50%                    1.0
# 75%                    1.0
# max                    1.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2652 entries, 0 to 37418
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   video_id             2652 non-null   object
#  1   title                2652 non-null   object
#  2   channel_id           2652 non-null   object
#  3   channel_title        2652 non-null   object
#  4   published_at         2652 non-null   datetime64[ns]
#  5   view_count           2652 non-null   int64
#  6   likes                2652 non-null   int64
#  7   dislikes             2652 non-null   int64
#  8   comment_count        2652 non-null   int64
#  9   tags                 2652 non-null   object
#  10  description          2652 non-null   object
#  11  comments             2640 non-null   object
#  12  published_month_num  2652 non-null   int64
#  13  published_month      2652 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(8)
# memory usage: 310.8+ KB
# None
# ****************************************************************************************************
#          view_count         likes       dislikes  comment_count  \
# count  2.652000e+03  2.652000e+03    2652.000000   2.652000e+03
# mean   4.896377e+06  1.459908e+05    4272.257164   9.196232e+03
# std    1.475755e+07  3.961011e+05   20264.769436   5.677935e+04
# min    2.036800e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.941495e+05  1.262700e+04     273.750000   9.147500e+02
# 50%    1.240674e+06  3.970900e+04     759.000000   2.355000e+03
# 75%    3.693094e+06  1.209325e+05    2346.000000   6.326250e+03
# max    2.497840e+08  9.008309e+06  550853.000000   2.516058e+06
#
#        published_month_num
# count               2652.0
# mean                   1.0
# std                    0.0
# min                    1.0
# 25%                    1.0
# 50%                    1.0
# 75%                    1.0
# max                    1.0
